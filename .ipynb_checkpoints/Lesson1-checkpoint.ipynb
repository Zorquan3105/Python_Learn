# %%
import pandas as pd
import numpy as np
import math



kikstarter = pd.read_csv('kickstarter.csv')


# kikstarter

# kikstarter.shape
# len(kikstarter)

# Вывод данных с начала конца или рандомные из набора данных
# kikstarter.head(5)
# kikstarter.tail(5)
# kikstarter.sample(5)
# 
# kikstarter.columns

# kikstarter['name'].head(12)

# kikstarter[['ID'],['name']].sample(12) СПРОСИТЬ !!! не работает

# kikstarter['main_category'].unique()
# kikstarter['main_category'].value_counts()


# kikstarter['main_category'].value_counts(normalize=True)*100 процентовка по категориям

# kikstarter.info()
# kikstarter['goal'].describe()
# kikstarter['main_category'].describe()

# kikstarter.iloc[10:20:2]




# kikstarter.iloc[10:20,2:2]

# kikstarter.loc[kikstarter['main_category']=='Games']

# Не работает !!
# kikstarter.loc[(kikstarter['main_category']=='Games'['name']) & (kikstarter['goal']>1000)] 



# Создание нового столбца
kikstarter=kikstarter.drop(columns=['ID','Unnamed', 'Unnamed: 0'])
                         
# kikstarter['new_column']= kikstarter['usd pledged']/1000
# kikstarter
# kikstarter.duplicated()


data=pd.DataFrame([[1,2,3],[1,2,3],[2,3,6]], columns=['a','b','c'])


data.loc[data.duplicated()]

# kikstarter.isna().sum()
kikstarter.dropna(subset=['name'],inplace=True)
kikstarter.dropna(subset=['backers'],inplace=True)
kikstarter.dropna(subset=['usd pledged'],inplace=True)
# перевод в дата 

kikstarter['launched'] = pd.to_datetime(kikstarter['launched'])
kikstarter['deadline'] = pd.to_datetime(kikstarter['deadline'])




kikstarter['year'] = kikstarter['launched'].dt.year
kikstarter['month'] = kikstarter['launched'].dt.month
kikstarter['day of week'] =kikstarter['launched'].dt.dayofweek 
kikstarter['hour'] = kikstarter['launched'].dt.hour



kikstarter['goal']=kikstarter['goal'].apply(math.ceil)


kikstarter['goal']=kikstarter['goal'].astype('int')




#Работает !!!
kikstarter.loc[(kikstarter['currency'].isna()) & (kikstarter['country']=='US'),['currency']] = 'USD'

kikstarter.loc[(kikstarter['currency'].isna()) & (kikstarter['country']=='CA'),['currency']] = 'CAD'

kikstarter.loc[(kikstarter['currency'].isna()) & (kikstarter['country']=='GB'),['currency']] = 'GBP'

kikstarter.loc[(kikstarter['currency'].isna()) & (kikstarter['country']=='SE'),['currency']] = 'SEK'

kikstarter.loc[(kikstarter['currency'].isna()) & (kikstarter['country']=='AU'),['currency']] = 'AUD'

kikstarter.loc[(kikstarter['currency'].isna()) & (kikstarter['country']=='MX'),['currency']] = 'MXN'

kikstarter.loc[(kikstarter['currency'].isna()) & (kikstarter['country']=='NO'),['currency']] = 'NOK'

kikstarter.loc[(kikstarter['currency'].isna()) & (kikstarter['country']=='NZ'),['currency']] = 'NZD'

kikstarter.loc[(kikstarter['currency'].isna()) & (kikstarter['country']=='NL'),['currency']] = 'EUR'

kikstarter.loc[(kikstarter['currency'].isna()) & (kikstarter['country']=='CH'),['currency']] = 'CHF'

kikstarter.loc[(kikstarter['currency'].isna()) & (kikstarter['country']=='DK'),['currency']] = 'DKK'

kikstarter.loc[(kikstarter['currency'].isna()) & (kikstarter['country']=='SG'),['currency']] = 'SGD'

kikstarter.loc[(kikstarter['currency'].isna()) & (kikstarter['country']=='HK'),['currency']] = 'HKD'

kikstarter.loc[(kikstarter['currency'].isna()) & (kikstarter['country']=='JP'),['currency']] = 'JPY'

# Все страны которые используют евро можно объединить в одно условие будет менее читабельно так что оставил так 
# там всё будет на подобии  ((kikstarter['country']=='FR') | (kikstarter['country']=='DE') )
kikstarter.loc[(kikstarter['currency'].isna()) & (kikstarter['country']=='FR'),['currency']] = 'EUR'
kikstarter.loc[(kikstarter['currency'].isna()) & (kikstarter['country']=='DE'),['currency']] = 'EUR'
kikstarter.loc[(kikstarter['currency'].isna()) & (kikstarter['country']=='ES'),['currency']] = 'EUR'
kikstarter.loc[(kikstarter['currency'].isna()) & (kikstarter['country']=='AT'),['currency']] = 'EUR'
kikstarter.loc[(kikstarter['currency'].isna()) & (kikstarter['country']=='IT'),['currency']] = 'EUR'
kikstarter.loc[(kikstarter['currency'].isna()) & (kikstarter['country']=='BE'),['currency']] = 'EUR'
kikstarter.loc[(kikstarter['currency'].isna()) & (kikstarter['country']=='LU'),['currency']] = 'EUR'
kikstarter.loc[(kikstarter['currency'].isna()) & (kikstarter['country']=='IE'),['currency']] = 'EUR'




test = kikstarter.loc[kikstarter['currency'].isna()]
test
# Out:
# Empty DataFrame
# Columns: [name, category, main_category, currency, deadline, goal, launched, pledged, state, backers, country, usd pledged, usd_pledged_real, usd_goal_real, year, month, day of week, hour]
# Index: []

# %%
kikstarter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 374673 entries, 0 to 378660
# Data columns (total 18 columns):
# name                374673 non-null object
# category            374673 non-null object
# main_category       374673 non-null object
# currency            374673 non-null object
# deadline            374673 non-null datetime64[ns]
# goal                374673 non-null int32
# launched            374673 non-null datetime64[ns]
# pledged             374673 non-null float64
# state               374673 non-null object
# backers             374673 non-null float64
# country             374673 non-null object
# usd pledged         374673 non-null float64
# usd_pledged_real    374673 non-null float64
# usd_goal_real       374673 non-null float64
# year                374673 non-null int64
# month               374673 non-null int64
# day of week         374673 non-null int64
# hour                374673 non-null int64
# dtypes: datetime64[ns](2), float64(5), int32(1), int64(4), object(6)
# memory usage: 52.9+ MB

# %%
kinopoisk = pd.read_csv('Kinopoisk.csv',sep=';')
# kinopoisk
# eror_bag_lines или как то так если файл не читается или как минимум узнать тип разделителя

# %%
kikstarter.isna().sum()
# Out:
# name                0
# category            0
# main_category       0
# currency            0
# deadline            0
# goal                0
# launched            0
# pledged             0
# state               0
# backers             0
# country             0
# usd pledged         0
# usd_pledged_real    0
# usd_goal_real       0
# year                0
# month               0
# day of week         0
# hour                0
# dtype: int64

# %%
kikstarter.iloc[10:200]
# Out:
#                                                   name          category  \
# 10                                 Of Jesus and Madmen        Nonfiction
# 11                                    Lisa Lim New CD!        Indie Rock
# 12                                  The Cottage Market            Crafts
# 13   G-Spot Place for Gamers to connect with eachot...             Games
# 14   Tombstone: Old West tabletop game and miniatur...    Tabletop Games
# 15                                      Survival Rings            Design
# 16                                           The Beard       Comic Books
# 17                    Notes From London: Above & Below         Art Books
# 18                 Mike Corey's Darkness & Light Album             Music
# 19                                            Boco Tea              Food
# 20               CMUK. Shoes: Take on Life Feet First.           Fashion
# 21                    MikeyJ clothing brand fundraiser     Childrenswear
# 22                      Alice in Wonderland in G Minor           Theater
# 23   Mountain brew: A quest for alcohol sustainability            Drinks
# 24                         The Book Zoo - A Mini-Comic            Comics
# 25   Matt Cavenaugh & Jenny Powers make their 1st a...             Music
# 26                                Superhero Teddy Bear               DIY
# 27                                 Permaculture Skills         Webseries
# 28   Rebel Army Origins: The Heroic Story Of Major ...            Comics
# 29                       My Moon - Animated Short Film         Animation
# 30                                   Daily Brew Coffee       Food Trucks
# 31                   Ledr workbook: one tough journal!    Product Design
# 32             Feather Cast Furled Fly Fishing Leaders    Product Design
# 33                                              BB130A        Public Art
# 34             Chris Eger Band - New Nashville Record!             Music
# 35                                    Squatch Watchers         Webseries
# 36                          Arrows & Sound Debut Album        Indie Rock
# 37   Zen in America: a film on Zen Buddhism in Nort...       Documentary
# 38                          Galaxy: Winnie and Friends      Illustration
# 188      failed      2.0      US        30.00             30.00
# 189  successful    164.0      US     20313.00          20313.00
# 190  successful     19.0      US       850.00            850.00
# 191  successful     40.0      US       642.00            642.00
# 192      failed     18.0      US       113.00            113.00
# 193  successful     69.0      US     18009.00          18009.00
# 194  successful     24.0      MX         2.45           2739.22
# 195      failed      0.0      US         0.00              0.00
# 196      failed      3.0      US         0.00              3.69
# 197      failed     15.0      GB       115.05            423.72
# 198      failed      1.0      GB        19.40             19.72
# 199  successful    107.0      GB      4983.78           4848.23
# 200  successful    120.0      US     39209.00          39209.00
#
#      usd_goal_real  year  month  day of week  hour
# 10         2406.39  2013      9            0    18
# 11        12500.00  2013      3            5     6
# 12         5000.00  2014      9            1    17
# 13       200000.00  2016      2            1    23
# 14         6469.73  2017      4            2    19
# 15         2500.00  2015      1            3     2
# 16         1500.00  2014     10            3    22
# 17         3000.00  2015      4            4    21
# 18          250.00  2012      8            3    14
# 19         5000.00  2012      5            3    17
# 20        20000.00  2013     11            0     7
# 21         2026.10  2017      8            1     1
# 22         3500.00  2014      5            4    10
# 23           65.55  2015      1            0    19
# 24          175.00  2014     10            3    17
# 25        10000.00  2010     12            1    23
# 26        17489.65  2015     12            6    20
# 27        15313.04  2014     11            4    18
# 28          142.91  2015     12            1    16
# 29        50000.00  2017      4            0    17
# 30         5181.12  2015      3            6    18
# 31         1000.00  2016      9            2    13
# 32         1427.35  2015      7            3     3
# 33        25000.00  2013      2            1     1
# 34        12000.00  2014      7            0    22
# 35        10000.00  2013      7            2    21
# 36         4000.00  2012      4            3     1
# 37        10000.00  2013      9            5    23
# 38         3000.00  2015     12            2    21
# 39        15000.00  2012      8            4    18
# ..             ...   ...    ...          ...   ...
# 171       32000.00  2014     11            4    18
# 172         777.00  2011     10            3    23
# 173        7500.00  2016      7            2    16
# 174       50000.00  2013      1            5    18
# 175       80000.00  2016      1            3    12
# 176        2000.00  2010     10            1     1
# 177        9500.00  2015      2            0    19
# 178        5000.00  2013     10            2    21
# 179       10000.00  2015      8            3    22
# 180         856.00  2014      6            1    10
# 181       50000.00  2015      5            6    21
# 182        4000.00  2016      9            3    15
# 183        5000.00  2017     12            5    20
# 184       30000.00  2016     10            0     3
# 185        8592.68  2013      5            0    13
# 186        5000.00  2014      9            1    20
# 187       64074.84  2012     11            3    13
# 188        4000.00  2010      7            4    23
# 189       19650.00  2014      6            0     9
# 190         800.00  2011     12            4     0
# 191         275.00  2015      1            5     4
# 192       14000.00  2014     12            4     7
# 193       15000.00  2016      5            5     0
# 194        2658.03  2016     11            5     4
# 195        2500.00  2015     11            3     7
# 196        2000.00  2017      8            2     9
# 197       12554.61  2017      1            2    16
# 198         262.92  2017      7            3    17
# 199        3913.65  2014     10            6    20
# 200       35000.00  2015      6            0    17
#
# [190 rows x 18 columns]

# %% [markdown]
# LESSON 2
